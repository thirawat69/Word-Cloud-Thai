# %% [markdown]
# # Collect Tweets into MongoDB

# %% [markdown]
# ## Install Python libraries
#
# You may need to restart your Jupyter Notebook instance after installed those libraries.

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\thirawat\anaconda3\lib\site-packages (4.0.1)

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\thirawat\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\thirawat\anaconda3\lib\site-packages (from pymongo[srv]) (2.1.0)

# %%
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in c:\users\thirawat\anaconda3\lib\site-packages (2.1.0)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\thirawat\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\thirawat\anaconda3\lib\site-packages (from tweepy) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\thirawat\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\thirawat\anaconda3\lib\site-packages (from tweepy) (2.26.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\thirawat\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thirawat\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thirawat\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thirawat\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thirawat\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.0.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\thirawat\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\thirawat\anaconda3\lib\site-packages (1.19.3)

# %%
pip install certifi
# Out:
# Requirement already satisfied: certifi in c:\users\thirawat\anaconda3\lib\site-packages (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Python libraries

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd
import certifi

# %% [markdown]
# ##  Load the Authorization Info

# %% [markdown]
# Save database connection info and API Keys in a config.ini file and use the configparse to load the authorization info.

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']

# %% [markdown]
# ## Connect to the MongoDB Cluster

# %%
ca = certifi.where()
client = MongoClient(mongod_connect , tlsCAFile=ca) # connect to mongo and fix SSL problem with tlsCAFile=ca
db = client.Twitter # use or create a database named Twitter
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'id_1'

# %% [markdown]
# ## Use the Streaming API to Collect Tweets

# %% [markdown]
# Authorize the Stream API

# %%
stream_auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
stream_auth.set_access_token(OAUTH_TOKEN, OATH_TOKEN_SECRET)

strem_api = tweepy.API(stream_auth)

# %% [markdown]
# Define the query for the Stream API

# %%
track = ['#ม็อบ12ธันวา64'] # define the keywords, tweets contain election

# locations = [-78.9326449,38.4150904,-78.8816972,38.4450731] #defin the location, in Harrisonburg, VA

# %% [markdown]
# The collected tweets will contain 'election' <span style="color:red;font-weight:bold"> OR </span> are located in Harrisonburg, VA

# %%
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        print (status.id_str)
        try:
            tweet_collection.insert_one(status._json)
        except:
            pass
  
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = strem_api.auth, listener=myStreamListener)
myStream.filter(track=track)#  (locations = locations)   #Use either track or locations
# Out:
# 1470572249409220608
# 1470572256887640064
# 1470572277062201348
# 1470572279910191108
# 1470572300172890114
# 1470572302806884353
# 1470572307902984194
# 1470572310734114818
# 1470572315301662720
# 1470572320108720131
# 1470572321249558529
# 1470572344355672069
# 1470572345290989571
# 1470572347266453506
# 1470572347727880193
# 1470572349103611905
# 1470572356640796674
# 1470572394834055180
# 1470572394829860866
# 1470572411468726277
# 1470572428237500418
# 1470572448592531461
# 1470572449687162887
# 1470572468775522304
# 1470572471653134343
# 1470572525965168640
# 1470572531190943751
# 1470572539239829507
# 1470572553580150784
# 1470572571871514633
# 1470572575851876356
# 1470572581992349698
# 1470572584815058946
# 1470572588124364801
# 1470572616008171520
# 1470572634316308480
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-11bc45f21258> in <module>
#      13 myStreamListener = MyStreamListener()
#      14 myStream = tweepy.Stream(auth = strem_api.auth, listener=myStreamListener)
# ---> 15 myStream.filter(track=track)#  (locations = locations)   #Use either track or locations
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     490
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#     494         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     585         try:
#     586             while True:
# --> 587                 chunk_left = self._get_chunk_left()
#     588                 if chunk_left is None:
#     589                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     553                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     554             try:
# --> 555                 chunk_left = self._read_next_chunk_size()
#     556             except ValueError:
#     557                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     513     def _read_next_chunk_size(self):
#     514         # Read the next chunk size from the file
# --> 515         line = self.fp.readline(_MAXLINE + 1)
#     516         if len(line) > _MAXLINE:
#     517             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Use the REST API to Collect Tweets

# %% [markdown]
# Authorize the REST API

# %%
rest_auth = twitter.oauth.OAuth(OAUTH_TOKEN,OATH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
rest_api = twitter.Twitter(auth=rest_auth)

# %% [markdown]
# Define the query for the REST API

# %%
count = 10 #number of returned tweets, default and max is 100
geocode = "38.4392897,-78.9412224,50mi"  # defin the location, in Harrisonburg, VA
q = "#ผู้ว่ากทม"                            #define the keywords, tweets contain election

# %% [markdown]
# The collected tweets will contain '#ผู้ว่ากทม' <span style="color:red;font-weight:bold"> AND </span> are located in Harrisonburg, VA

# %%
#search_results = rest_api.search.tweets( count=count,q=q, geocode=geocode)
search_results = rest_api.search.tweets( count=count,q=q) #you can use both q and geocode
statuses = search_results["statuses"]
since_id_new = statuses[-1]['id']
i=1
for statuse in statuses:
    try:
        tweet_collection.insert_one(statuse)
        pprint(statuse['created_at'])# print the date of the collected tweets
        i=i+1
    except:
        pass
print(i, "documents insert")
# Out:
# 'Tue Dec 14 02:30:37 +0000 2021'
# 'Tue Dec 14 02:30:36 +0000 2021'
# 'Tue Dec 14 02:30:36 +0000 2021'
# 'Tue Dec 14 02:30:32 +0000 2021'
# 'Tue Dec 14 02:30:26 +0000 2021'
# 'Tue Dec 14 02:30:25 +0000 2021'
# 'Tue Dec 14 02:30:24 +0000 2021'
# 'Tue Dec 14 02:30:21 +0000 2021'
# 'Tue Dec 14 02:30:21 +0000 2021'
# 'Tue Dec 14 02:30:21 +0000 2021'
# 'Tue Dec 14 02:30:19 +0000 2021'
# 'Tue Dec 14 02:30:19 +0000 2021'
# 'Tue Dec 14 02:30:12 +0000 2021'
# 'Tue Dec 14 02:30:08 +0000 2021'
# 'Tue Dec 14 02:30:06 +0000 2021'
# 'Tue Dec 14 02:30:05 +0000 2021'
# 'Tue Dec 14 02:30:02 +0000 2021'
# 'Tue Dec 14 02:29:49 +0000 2021'
# 'Tue Dec 14 02:29:48 +0000 2021'
# 'Tue Dec 14 02:29:48 +0000 2021'
# 'Tue Dec 14 02:29:45 +0000 2021'
# 'Tue Dec 14 02:29:44 +0000 2021'
# 'Tue Dec 14 02:29:43 +0000 2021'
# 'Tue Dec 14 02:29:42 +0000 2021'
# 'Tue Dec 14 02:29:42 +0000 2021'
# 'Tue Dec 14 02:29:41 +0000 2021'
# 'Tue Dec 14 02:29:36 +0000 2021'
# 'Tue Dec 14 02:29:35 +0000 2021'
# 'Tue Dec 14 02:29:33 +0000 2021'
# 'Tue Dec 14 02:29:31 +0000 2021'
# 'Tue Dec 14 02:29:29 +0000 2021'
# 'Tue Dec 14 02:29:28 +0000 2021'
# 'Tue Dec 14 02:29:26 +0000 2021'
# 'Tue Dec 14 02:29:24 +0000 2021'
# 'Tue Dec 14 02:29:24 +0000 2021'
# 'Tue Dec 14 02:29:22 +0000 2021'
# 'Tue Dec 14 02:29:20 +0000 2021'
# 'Tue Dec 14 02:29:19 +0000 2021'
# 'Tue Dec 14 02:29:18 +0000 2021'
# 'Tue Dec 14 02:29:16 +0000 2021'
# 'Tue Dec 14 02:29:13 +0000 2021'
# 'Tue Dec 14 02:29:11 +0000 2021'
# 'Tue Dec 14 02:29:10 +0000 2021'
# 'Tue Dec 14 02:29:10 +0000 2021'
# 'Tue Dec 14 02:29:10 +0000 2021'
# 'Tue Dec 14 02:29:09 +0000 2021'
# 'Tue Dec 14 02:29:07 +0000 2021'
# 'Tue Dec 14 02:29:03 +0000 2021'
# 'Tue Dec 14 02:29:00 +0000 2021'
# 'Tue Dec 14 02:28:58 +0000 2021'
# 'Tue Dec 14 02:28:58 +0000 2021'
# 'Tue Dec 14 02:28:57 +0000 2021'
# 'Tue Dec 14 02:28:54 +0000 2021'
# 'Tue Dec 14 02:28:54 +0000 2021'
# 'Tue Dec 14 02:28:49 +0000 2021'
# 'Tue Dec 14 02:28:41 +0000 2021'
# 'Tue Dec 14 02:28:40 +0000 2021'
# 'Tue Dec 14 02:28:39 +0000 2021'
# 'Tue Dec 14 02:28:39 +0000 2021'
# 'Tue Dec 14 02:28:37 +0000 2021'
# 'Tue Dec 14 02:28:36 +0000 2021'
# 'Tue Dec 14 02:28:35 +0000 2021'
# 'Tue Dec 14 02:28:32 +0000 2021'
# 'Tue Dec 14 02:28:29 +0000 2021'
# 'Tue Dec 14 02:28:29 +0000 2021'
# 'Tue Dec 14 02:28:28 +0000 2021'
# 'Tue Dec 14 02:28:26 +0000 2021'
# 'Tue Dec 14 02:28:24 +0000 2021'
# 'Tue Dec 14 02:28:23 +0000 2021'
# 'Tue Dec 14 02:28:21 +0000 2021'
# 'Tue Dec 14 02:28:20 +0000 2021'
# 'Tue Dec 14 02:28:19 +0000 2021'
# 'Tue Dec 14 02:28:19 +0000 2021'
# 'Tue Dec 14 02:28:19 +0000 2021'
# 'Tue Dec 14 02:28:17 +0000 2021'
# 'Tue Dec 14 02:28:11 +0000 2021'
# 'Tue Dec 14 02:28:10 +0000 2021'
# 'Tue Dec 14 02:28:02 +0000 2021'
# 'Tue Dec 14 02:27:59 +0000 2021'
# 'Tue Dec 14 02:27:55 +0000 2021'
# 'Tue Dec 14 02:27:53 +0000 2021'
# 'Tue Dec 14 02:27:53 +0000 2021'
# 'Tue Dec 14 02:27:49 +0000 2021'
# 'Tue Dec 14 02:27:48 +0000 2021'
# 'Tue Dec 14 02:27:43 +0000 2021'
# 'Tue Dec 14 02:27:43 +0000 2021'
# 'Tue Dec 14 02:27:34 +0000 2021'
# 'Tue Dec 14 02:27:33 +0000 2021'
# 'Tue Dec 14 02:27:33 +0000 2021'
# 'Tue Dec 14 02:27:30 +0000 2021'
# 'Tue Dec 14 02:27:28 +0000 2021'
# 'Tue Dec 14 02:27:26 +0000 2021'
# 'Tue Dec 14 02:27:21 +0000 2021'
# 'Tue Dec 14 02:27:16 +0000 2021'
# 'Tue Dec 14 02:27:16 +0000 2021'
# 'Tue Dec 14 02:27:10 +0000 2021'
# 'Tue Dec 14 02:27:05 +0000 2021'
# 'Tue Dec 14 02:27:01 +0000 2021'
# 'Tue Dec 14 02:27:00 +0000 2021'
# 'Tue Dec 14 02:26:59 +0000 2021'
# 101 documents insert

# %%
print("you have ",tweet_collection.count_documents({}),"document in collection")
# Out:
# you have  214 document in collection

# %%
print(since_id_new)
# Out:
# 1470578305942179843

# %% [markdown]
# ## View the Collected Tweets

# %% [markdown]
# Print the number of tweets and unique twitter users

# %%
print(tweet_collection.estimated_document_count())# number of tweets collected

user_cursor = tweet_collection.distinct("user.id")
print (len(user_cursor)) # number of unique Twitter users
# Out:
# 214
# 163

# %% [markdown]
# ## ลองสร้าง loop เอง

# %% [markdown]
# Continue fetching early tweets with the same query.
# <p><span style="color:red;font-weight:bold">YOU WILL REACH YOUR RATE LIMIT VERY FAST</span></p>

# %%
start = tweet_collection.count_documents({}) # จำนวนคอลเลกชั่นที่มีในปัจจุบัน
count = 1000 #number of returned tweets, default and max is 1000
q = "#ผู้ว่ากทม"                            #define the keywords, tweets contain election
print("start = ",start)
# Out:
# start =  314

# %%
since_id_old = 0
since_id_new = start+count
i=1

while(since_id_new != since_id_old):
    search_results = rest_api.search.tweets( count=count,q=q) #you can use both q and geocode
    statuses = search_results["statuses"]
    since_id_new = statuses[-1]['id']
    for statuse in statuses:
        try:
            tweet_collection.insert_one(statuse)
            print(i, "documents insert")
            i=i+1
        except:
            pass
# Out:
# 1 documents insert
# 2 documents insert
# 3 documents insert
# 4 documents insert
# 5 documents insert
# 6 documents insert
# 7 documents insert
# 8 documents insert
# 9 documents insert
# 10 documents insert
# 11 documents insert
# 12 documents insert
# 13 documents insert
# 14 documents insert
# 15 documents insert
# 16 documents insert
# 17 documents insert
# 18 documents insert
# 19 documents insert
# 20 documents insert
# 21 documents insert
# 22 documents insert
# 23 documents insert
# 24 documents insert
# 25 documents insert
# 26 documents insert
# 27 documents insert
# 28 documents insert
# 29 documents insert
# 30 documents insert
# 31 documents insert
# 32 documents insert
# 33 documents insert
# 34 documents insert
# 35 documents insert
# 36 documents insert
# 37 documents insert
# 38 documents insert
# 39 documents insert
# 40 documents insert
# 41 documents insert
# 42 documents insert
# 43 documents insert
# 44 documents insert
# 45 documents insert
# 46 documents insert
# 47 documents insert
# 48 documents insert
# 49 documents insert
# 50 documents insert
# 51 documents insert
# 52 documents insert
# 53 documents insert
# 54 documents insert
# 55 documents insert
# 56 documents insert
# 57 documents insert
# 58 documents insert
# 59 documents insert
# 60 documents insert
# 61 documents insert
# 62 documents insert
# 63 documents insert
# 64 documents insert
# 65 documents insert
# 66 documents insert
# 67 documents insert
# 68 documents insert
# 69 documents insert
# 70 documents insert
# 71 documents insert
# 72 documents insert
# 73 documents insert
# 74 documents insert
# 75 documents insert
# 76 documents insert
# 77 documents insert
# 78 documents insert
# 79 documents insert
# 80 documents insert
# 81 documents insert
# 82 documents insert
# 83 documents insert
# 84 documents insert
# 85 documents insert
# 86 documents insert
# 87 documents insert
# 88 documents insert
# 89 documents insert
# 90 documents insert
# 91 documents insert
# 92 documents insert
# 93 documents insert
# 94 documents insert
# 95 documents insert
# 96 documents insert
# 97 documents insert
# 98 documents insert
# 99 documents insert
# 100 documents insert
# 101 documents insert
# 102 documents insert
# 103 documents insert
# 104 documents insert
# 105 documents insert
# 106 documents insert
# 107 documents insert
# 108 documents insert
# 109 documents insert
# 110 documents insert
# 111 documents insert
# 112 documents insert
# 113 documents insert
# 114 documents insert
# 115 documents insert
# 116 documents insert
# 117 documents insert
# 118 documents insert
# 119 documents insert
# 120 documents insert
# 121 documents insert
# 122 documents insert
# 123 documents insert
# 124 documents insert
# 125 documents insert
# 126 documents insert
# 127 documents insert
# 128 documents insert
# 129 documents insert
# 130 documents insert
# 131 documents insert
# 132 documents insert
# 133 documents insert
# 134 documents insert
# 135 documents insert
# 136 documents insert
# 137 documents insert
# 138 documents insert
# 139 documents insert
# 140 documents insert
# 141 documents insert
# 142 documents insert
# 143 documents insert
# 144 documents insert
# 145 documents insert
# 146 documents insert
# 147 documents insert
# 148 documents insert
# 149 documents insert
# 150 documents insert
# 151 documents insert
# 152 documents insert
# 153 documents insert
# 154 documents insert
# 155 documents insert
# 156 documents insert
# 157 documents insert
# 158 documents insert
# 159 documents insert
# 160 documents insert
# 161 documents insert
# 162 documents insert
# 163 documents insert
# 164 documents insert
# 165 documents insert
# 166 documents insert
# 167 documents insert
# 168 documents insert
# 169 documents insert
# 170 documents insert
# 171 documents insert
# 172 documents insert
# 173 documents insert
# 174 documents insert
# 175 documents insert
# 176 documents insert
# 177 documents insert
# 178 documents insert
# 179 documents insert
# 180 documents insert
# 181 documents insert
# 182 documents insert
# 183 documents insert
# 184 documents insert
# 185 documents insert
# 186 documents insert
# 187 documents insert
# 188 documents insert
# 189 documents insert
# 190 documents insert
# 191 documents insert
# 192 documents insert
# 193 documents insert
# 194 documents insert
# 195 documents insert
# 196 documents insert
# 197 documents insert
# 198 documents insert
# 199 documents insert
# 200 documents insert
# 201 documents insert
# 202 documents insert
# 203 documents insert
# 204 documents insert
# 205 documents insert
# 206 documents insert
# 207 documents insert
# 208 documents insert
# 209 documents insert
# 210 documents insert
# 211 documents insert
# 212 documents insert
# 213 documents insert
# 214 documents insert
# 215 documents insert
# 216 documents insert
# 217 documents insert
# 218 documents insert
# 219 documents insert
# 220 documents insert
# 221 documents insert
# 222 documents insert
# 223 documents insert
# 224 documents insert
# 225 documents insert
# 226 documents insert
# 227 documents insert
# 228 documents insert
# 229 documents insert
# 230 documents insert
# 231 documents insert
# 232 documents insert
# 233 documents insert
# 234 documents insert
# 235 documents insert
# 236 documents insert
# 237 documents insert
# 238 documents insert
# 239 documents insert
# 240 documents insert
# 241 documents insert
# 242 documents insert
# 243 documents insert
# 244 documents insert
# 245 documents insert
# 246 documents insert
# 247 documents insert
# 248 documents insert
# 249 documents insert
# 250 documents insert
# 251 documents insert
# 252 documents insert
# 253 documents insert
# 254 documents insert
# 255 documents insert
# 256 documents insert
# 257 documents insert
# 258 documents insert
# 259 documents insert
# 260 documents insert
# 261 documents insert
# 262 documents insert
# 263 documents insert
# 264 documents insert
# 265 documents insert
# 266 documents insert
# 267 documents insert
# 268 documents insert
# 269 documents insert
# 270 documents insert
# 271 documents insert
# 272 documents insert
# 273 documents insert
# 274 documents insert
# 275 documents insert
# 276 documents insert
# 277 documents insert
# 278 documents insert
# 279 documents insert
# 280 documents insert
# 281 documents insert
# 282 documents insert
# 283 documents insert
# 284 documents insert
# 285 documents insert
# 286 documents insert
# 287 documents insert
# 288 documents insert
# 289 documents insert
# 290 documents insert
# 291 documents insert
# 292 documents insert
# 293 documents insert
# 294 documents insert
# 295 documents insert
# 296 documents insert
# 297 documents insert
# 298 documents insert
# 299 documents insert
# 300 documents insert
# 301 documents insert
# 302 documents insert
# 303 documents insert
# 304 documents insert
# 305 documents insert
# 306 documents insert
# 307 documents insert
# 308 documents insert
# 309 documents insert
# 310 documents insert
# 311 documents insert
# 312 documents insert
# 313 documents insert
# 314 documents insert
# 315 documents insert
# 316 documents insert
# 317 documents insert
# 318 documents insert
# 319 documents insert
# 320 documents insert
# 321 documents insert
# 322 documents insert
# 323 documents insert
# 324 documents insert
# 325 documents insert
# 326 documents insert
# 327 documents insert
# 328 documents insert
# 329 documents insert
# 330 documents insert
# 331 documents insert
# 332 documents insert
# 333 documents insert
# 334 documents insert
# 335 documents insert
# 336 documents insert
# 337 documents insert
# 338 documents insert
# 339 documents insert
# 340 documents insert
# 341 documents insert
# 342 documents insert
# 343 documents insert
# 344 documents insert
# 345 documents insert
# 346 documents insert
# 347 documents insert
# 348 documents insert
# 349 documents insert
# 350 documents insert
# 351 documents insert
# 352 documents insert
# 353 documents insert
# 354 documents insert
# 355 documents insert
# 356 documents insert
# 357 documents insert
# 358 documents insert
# 359 documents insert
# 360 documents insert
# 361 documents insert
# 362 documents insert
# 363 documents insert
# 364 documents insert
# 365 documents insert
# 366 documents insert
# 367 documents insert
# 368 documents insert
# 369 documents insert
# 370 documents insert
# 371 documents insert
# 372 documents insert
# 373 documents insert
# 374 documents insert
# 375 documents insert
# 376 documents insert
# 377 documents insert
# 378 documents insert
# 379 documents insert
# 380 documents insert
# 381 documents insert
# 382 documents insert
# 383 documents insert
# 384 documents insert
# 385 documents insert
# 386 documents insert
# 387 documents insert
# 388 documents insert
# 389 documents insert
# 390 documents insert
# 391 documents insert
# 392 documents insert
# 393 documents insert
# 394 documents insert
# 395 documents insert
# 396 documents insert
# 397 documents insert
# 398 documents insert
# 399 documents insert
# 400 documents insert
# 401 documents insert
# 402 documents insert
# 403 documents insert
# 404 documents insert
# 405 documents insert
# 406 documents insert
# 407 documents insert
# 408 documents insert
# 409 documents insert
# 410 documents insert
# 411 documents insert
# 412 documents insert
# 413 documents insert
# 414 documents insert
# 415 documents insert
# 416 documents insert
# 417 documents insert
# 418 documents insert
# 419 documents insert
# 420 documents insert
# 421 documents insert
# 422 documents insert
# 423 documents insert
# 424 documents insert
# 425 documents insert
# 426 documents insert
# 427 documents insert
# 428 documents insert
# 429 documents insert
# 430 documents insert
# 431 documents insert
# 432 documents insert
# 433 documents insert
# 434 documents insert
# 435 documents insert
# 436 documents insert
# 437 documents insert
# 438 documents insert
# 439 documents insert
# 440 documents insert
# 441 documents insert
# 442 documents insert
# 443 documents insert
# 444 documents insert
# 445 documents insert
# 446 documents insert
# 447 documents insert
# 448 documents insert
# 449 documents insert
# 450 documents insert
# 451 documents insert
# 452 documents insert
# 453 documents insert
# 454 documents insert
# 455 documents insert
# 456 documents insert
# 457 documents insert
# 458 documents insert
# 459 documents insert
# 460 documents insert
# 461 documents insert
# 462 documents insert
# 463 documents insert
# 464 documents insert
# 465 documents insert
# 466 documents insert
# 467 documents insert
# 468 documents insert
# 469 documents insert
# 470 documents insert
# 471 documents insert
# 472 documents insert
# 473 documents insert
# 474 documents insert
# 475 documents insert
# 476 documents insert
# 477 documents insert
# 478 documents insert
# 479 documents insert
# 480 documents insert
# 481 documents insert
# 482 documents insert
# 483 documents insert
# 484 documents insert
# 485 documents insert
# 486 documents insert
# 487 documents insert
# 488 documents insert
# 489 documents insert
# 490 documents insert
# 491 documents insert
# 492 documents insert
# 493 documents insert
# 494 documents insert
# 495 documents insert
# 496 documents insert
# 497 documents insert
# 498 documents insert
# 499 documents insert
# 500 documents insert
# 501 documents insert
# 502 documents insert
# 503 documents insert
# 504 documents insert
# 505 documents insert
# 506 documents insert
# 507 documents insert
# 508 documents insert
# 509 documents insert
# 510 documents insert
# 511 documents insert
# 512 documents insert
# 513 documents insert
# 514 documents insert
# 515 documents insert
# 516 documents insert
# 517 documents insert
# 518 documents insert
# 519 documents insert
# 520 documents insert
# 521 documents insert
# 522 documents insert
# 523 documents insert
# 524 documents insert
# 525 documents insert
# 526 documents insert
# 527 documents insert
# 528 documents insert
# 529 documents insert
# 530 documents insert
# 531 documents insert
# 532 documents insert
# 533 documents insert
# 534 documents insert
# 535 documents insert
# 536 documents insert
# 537 documents insert
# 538 documents insert
# 539 documents insert
# 540 documents insert
# 541 documents insert
# 542 documents insert
# 543 documents insert
# 544 documents insert
# 545 documents insert
# 546 documents insert
# 547 documents insert
# 548 documents insert
# 549 documents insert
# 550 documents insert
# 551 documents insert
# 552 documents insert
# 553 documents insert
# 554 documents insert
# 555 documents insert
# 556 documents insert
# 557 documents insert
# 558 documents insert
# 559 documents insert
# 560 documents insert
# 561 documents insert
# 562 documents insert
# 563 documents insert
# 564 documents insert
# 565 documents insert
# 566 documents insert
# 567 documents insert
# 568 documents insert
# 569 documents insert
# 570 documents insert
# 571 documents insert
# 572 documents insert
# 573 documents insert
# 574 documents insert
# 575 documents insert
# 576 documents insert
# 577 documents insert
# 578 documents insert
# 579 documents insert
# 580 documents insert
# 581 documents insert
# 582 documents insert
# 583 documents insert
# 584 documents insert
# 585 documents insert
# 586 documents insert
# 587 documents insert
# 588 documents insert
# 589 documents insert
# 590 documents insert
# 591 documents insert
# 592 documents insert
# 593 documents insert
# 594 documents insert
# 595 documents insert
# 596 documents insert
# 597 documents insert
# 598 documents insert
# 599 documents insert
# 600 documents insert
# 601 documents insert
# 602 documents insert
# 603 documents insert
# 604 documents insert
# 605 documents insert
# 606 documents insert
# 607 documents insert
# 608 documents insert
# 609 documents insert
# 610 documents insert
# 611 documents insert
# 612 documents insert
# 613 documents insert
# 614 documents insert
# 615 documents insert
# 616 documents insert
# 617 documents insert
# 618 documents insert
# 619 documents insert
# 620 documents insert
# 621 documents insert
# 622 documents insert
# 623 documents insert
# 624 documents insert
# 625 documents insert
# 626 documents insert
# 627 documents insert
# 628 documents insert
# 629 documents insert
# 630 documents insert
# 631 documents insert
# 632 documents insert
# 633 documents insert
# 634 documents insert
# 635 documents insert
# 636 documents insert
# 637 documents insert
# 638 documents insert
# 639 documents insert
# 640 documents insert
# 641 documents insert
# 642 documents insert
# 643 documents insert
# 644 documents insert
# 645 documents insert
# 646 documents insert
# 647 documents insert
# 648 documents insert
# 649 documents insert
# 650 documents insert
# 651 documents insert
# 652 documents insert
# 653 documents insert
# 654 documents insert
# 655 documents insert
# 656 documents insert
# 657 documents insert
# 658 documents insert
# 659 documents insert
# 660 documents insert
# 661 documents insert
# 662 documents insert
# 663 documents insert
# 664 documents insert
# 665 documents insert
# 666 documents insert
# 667 documents insert
# 668 documents insert
# 669 documents insert
# 670 documents insert
# 671 documents insert
# 672 documents insert
# 673 documents insert
# 674 documents insert
# 675 documents insert
# 676 documents insert
# 677 documents insert
# 678 documents insert
# 679 documents insert
# 680 documents insert
# 681 documents insert
# 682 documents insert
# 683 documents insert
# 684 documents insert
# 685 documents insert
# 686 documents insert
# 687 documents insert
# 688 documents insert
# 689 documents insert
# 690 documents insert
# 691 documents insert
# 692 documents insert
# 693 documents insert
# 694 documents insert
# 695 documents insert
# 696 documents insert
# 697 documents insert
# 698 documents insert
# 699 documents insert
# 700 documents insert
# 701 documents insert
# 702 documents insert
# 703 documents insert
# 704 documents insert
# 705 documents insert
# 706 documents insert
# 707 documents insert
# 708 documents insert
# 709 documents insert
# 710 documents insert
# 711 documents insert
# 712 documents insert
# 713 documents insert
# 714 documents insert
# 715 documents insert
# 716 documents insert
# 717 documents insert
# 718 documents insert
# 719 documents insert
# 720 documents insert
# 721 documents insert
# 722 documents insert
# 723 documents insert
# 724 documents insert
# 725 documents insert
# 726 documents insert
# 727 documents insert
# 728 documents insert
# 729 documents insert
# 730 documents insert
# 731 documents insert
# 732 documents insert
# 733 documents insert
# 734 documents insert
# 735 documents insert
# 736 documents insert
# 737 documents insert
# 738 documents insert
# 739 documents insert
# 740 documents insert
# 741 documents insert
# 742 documents insert
# 743 documents insert
# 744 documents insert
# 745 documents insert
# 746 documents insert
# 747 documents insert
# 748 documents insert
# 749 documents insert
# 750 documents insert
# 751 documents insert
# 752 documents insert
# 753 documents insert
# 754 documents insert
# 755 documents insert
# 756 documents insert
# 757 documents insert
# 758 documents insert
# 759 documents insert
# 760 documents insert
# 761 documents insert
# 762 documents insert
# 763 documents insert
# 764 documents insert
# 765 documents insert
# 766 documents insert
# 767 documents insert
# 768 documents insert
# 769 documents insert
# 770 documents insert
# 771 documents insert
# 772 documents insert
# 773 documents insert
# 774 documents insert
# 775 documents insert
# 776 documents insert
# 777 documents insert
# 778 documents insert
# 779 documents insert
# 780 documents insert
# 781 documents insert
# 782 documents insert
# 783 documents insert
# 784 documents insert
# 785 documents insert
# 786 documents insert
# 787 documents insert
# 788 documents insert
# 789 documents insert
# 790 documents insert
# 791 documents insert
# 792 documents insert
# 793 documents insert
# 794 documents insert
# 795 documents insert
# 796 documents insert
# 797 documents insert
# 798 documents insert
# 799 documents insert
# 800 documents insert
# 801 documents insert
# 802 documents insert
# 803 documents insert
# 804 documents insert
# 805 documents insert
# 806 documents insert
# 807 documents insert
# 808 documents insert
# 809 documents insert
# 810 documents insert
# 811 documents insert
# 812 documents insert
# 813 documents insert
# 814 documents insert
# 815 documents insert
# 816 documents insert
# 817 documents insert
# 818 documents insert
# 819 documents insert
# 820 documents insert
# 821 documents insert
# 822 documents insert
# 823 documents insert
# 824 documents insert
# 825 documents insert
# 826 documents insert
# 827 documents insert
# 828 documents insert
# 829 documents insert
# 830 documents insert
# 831 documents insert
# 832 documents insert
# 833 documents insert
# 834 documents insert
# 835 documents insert
# 836 documents insert
# 837 documents insert
# 838 documents insert
# 839 documents insert
# 840 documents insert
# 841 documents insert
# 842 documents insert
# 843 documents insert
# 844 documents insert
# 845 documents insert
# 846 documents insert
# 847 documents insert
# 848 documents insert
# 849 documents insert
# 850 documents insert
# 851 documents insert
# 852 documents insert
# 853 documents insert
# 854 documents insert
# 855 documents insert
# 856 documents insert
# 857 documents insert
# 858 documents insert
# 859 documents insert
# 860 documents insert
# 861 documents insert
# 862 documents insert
# 863 documents insert
# 864 documents insert
# 865 documents insert
# 866 documents insert
# 867 documents insert
# 868 documents insert
# 869 documents insert
# 870 documents insert
# 871 documents insert
# 872 documents insert
# 873 documents insert
# 874 documents insert
# 875 documents insert
# 876 documents insert
# 877 documents insert
# 878 documents insert
# 879 documents insert
# 880 documents insert
# 881 documents insert
# 882 documents insert
# 883 documents insert
# 884 documents insert
# 885 documents insert
# 886 documents insert
# 887 documents insert
# 888 documents insert
# 889 documents insert
# 890 documents insert
# 891 documents insert
# 892 documents insert
# 893 documents insert
# 894 documents insert
# 895 documents insert
# 896 documents insert
# 897 documents insert
# 898 documents insert
# 899 documents insert
# 900 documents insert
# 901 documents insert
# 902 documents insert
# 903 documents insert
# 904 documents insert
# 905 documents insert
# 906 documents insert
# 907 documents insert
# 908 documents insert
# 909 documents insert
# 910 documents insert
# 911 documents insert
# 912 documents insert
# 913 documents insert
# 914 documents insert
# 915 documents insert
# 916 documents insert
# 917 documents insert
# 918 documents insert
# 919 documents insert
# 920 documents insert
# 921 documents insert
# 922 documents insert
# 923 documents insert
# 924 documents insert
# 925 documents insert
# 926 documents insert
# 927 documents insert
# 928 documents insert
# 929 documents insert
# 930 documents insert
# 931 documents insert
# 932 documents insert
# 933 documents insert
# 934 documents insert
# 935 documents insert
# 936 documents insert
# 937 documents insert
# 938 documents insert
# 939 documents insert
# 940 documents insert
# 941 documents insert
# 942 documents insert
# 943 documents insert
# 944 documents insert
# 945 documents insert
# 946 documents insert
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\twitter\api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     392                 try:
# --> 393                     res = json.loads(data.decode('utf8'))
#     394                 except json.decoder.JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#
# JSONDecodeError: Unterminated string starting at: line 1 column 701020 (char 701019)
#
# During handling of the above exception, another exception occurred:
#
# TwitterError                              Traceback (most recent call last)
# <ipython-input-82-89793b8a2ba4> in <module>
#       4
#       5 while(since_id_new != since_id_old):
# ----> 6     search_results = rest_api.search.tweets( count=count,q=q) #you can use both q and geocode
#       7     statuses = search_results["statuses"]
#       8     since_id_new = statuses[-1]['id']
#
# ~\anaconda3\lib\site-packages\twitter\api.py in __call__(self, **kwargs)
#     362             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     363         else:
# --> 364             return self._handle_response(req, uri, arg_data, _timeout)
#     365
#     366     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~\anaconda3\lib\site-packages\twitter\api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     395                     # it seems like the data received was incomplete
#     396                     # and we should catch it to allow retries
# --> 397                     raise TwitterError("Incomplete JSON data collected for %s (%s): %s)" % (uri, arg_data, e))
#     398                 return wrap_response(res, handle.headers)
#     399             else:
#
# TwitterError: Incomplete JSON data collected for 1.1/search/tweets (count=1000&oauth_consumer_key=OxrKX0tyCgKnJUVa4f31j2GQI&oauth_nonce=3825267853466788441&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1639451773&oauth_token=3313439336-HruZfbLk7sg1JBXfrQpHsLvulJkrTI7b1qX8J34&oauth_version=1.0&q=%23%E0%B8%9C%E0%B8%B9%E0%B9%89%E0%B8%A7%E0%B9%88%E0%B8%B2%E0%B8%81%E0%B8%97%E0%B8%A1&oauth_signature=EpjYtFIOISuW56QnLxv4gCUTmv4%3D): Unterminated string starting at: line 1 column 701020 (char 701019))

# %%
start = tweet_collection.count_documents({}) # จำนวนคอลเลกชั่นที่มีในปัจจุบัน
count = 1000 #number of returned tweets, default and max is 1000
q = "#ผู้ว่ากทม"                            #define the keywords, tweets contain election
print("now",start)
# Out:
# now 1260

# %%
id = 1470577854387666945
  
# fetching the status
status = strem_api.get_status(id)
  
# fetching the text attribute
text = status.text 
  
print("The text of the status is : \n\n" + text)
# Out:
# The text of the status is :
#
# RT @RadioKaKaKa: และก็ ไม่มีที่ไหนในโลกที่บอกว่า
# ปฎิรูป=ล้มล้าง
# #saveจะนะ #ผู้ว่ากทม #แอนชิลี https://t.co/DHx3o7rhxi
